# %%
import pandas as pd
import h5py as hp
import re
import datetime
import os
import numpy as np

# %%
data_index = pd.read_csv(r'\\00-2810-007\Shared\2024_LLO_Models\DataCollector.csv', dtype={'Structure': str})

# %%
data_index
# Out:
#    Structure         Weir                                          Path_Full  \
# 0      00035  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 1      00036  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 2      00037  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 3      00038  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 4      00039  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 5      00040  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 6      00041  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 7      00042  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 8      00048  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 9      00049  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 10     00050  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 11     00051  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 12     00052  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 13     00053  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 14     00054  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 15     00055  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 16     00056  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 17     00057  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 18     00058  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 19     00059  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 20     00060  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 21     00061  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 22     00099  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 23     60171  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 24     60172  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 25     60173  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 26     60176  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 27     60177  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 28     60178  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 29     60179  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 30     60181  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 31     60182  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 32     60184  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 33     60185  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 34     60186  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 35     60187  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 36     60188  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 37     60189  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 38     60190  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 39     60191  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 40     60192  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 41     60193  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
# 42     60194  Spencerport  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...
#
#                                             Path_Base StrucType  FlowIndex  \
# 0   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...      weir          0
# 1   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 2   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 3   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 4   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 5   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...      weir          0
# 6   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...      weir          0
# 7   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 8   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 9   \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 10  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 11  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   culvert          0
# 12  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   culvert          0
# 13  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 14  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 15  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 16  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 17  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 18  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 19  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 20  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 21  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 22  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   culvert          0
# 23  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 24  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 25  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 26  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 27  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 28  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 29  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 30  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 31  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   culvert          0
# 32  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 33  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 34  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 35  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 36  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 37  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 38  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   Culvert          0
# 39  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    bridge          0
# 40  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    Bridge          0
# 41  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...    Bridge          0
# 42  \\00-2810-007\Shared\2024_LLO_Models\Spencerpo...   culvert          0
#
#     HWIndex  TWIndex  AllIndex  Unnamed: 9
# 0         2        3        23         NaN
# 1         1        2        12         NaN
# 2         1        2        12         NaN
# 3         1        2        12         NaN
# 4         1        2        12         NaN
# 5         2        3        23         NaN
# 6         2        3        23         NaN
# 7         1        2        12         NaN
# 8         1        2        12         NaN
# 9         1        2        23         NaN
# 10        1        2        23         NaN
# 11        2        3        23         NaN
# 12        2        3        23         NaN
# 13        1        2        12         NaN
# 14        1        2        12         NaN
# 15        1        2        12         NaN
# 16        1        2        12         NaN
# 17        1        2        12         NaN
# 18        1        2        12         NaN
# 19        1        2        23         NaN
# 20        1        2        12         NaN
# 21        1        2        12         NaN
# 22        2        3        23         NaN
# 23        2        3        23         NaN
# 24        2        3        23         NaN
# 25        2        3        23         NaN
# 26        2        3        23         NaN
# 27        2        3        23         NaN
# 28        2        3        23         NaN
# 29        2        3        23         NaN
# 30        1        2        23         NaN
# 31        2        3        23         NaN
# 32        1        2        23         NaN
# 33        2        3        23         NaN
# 34        2        3        23         NaN
# 35        2        3        23         NaN
# 36        2        3        23         NaN
# 37        1        2        12         NaN
# 38        2        3        23         NaN
# 39        1        2        23         NaN
# 40        1        2        23         NaN
# 41        1        2        12         NaN
# 42        2        3        23         NaN

# %%
def get_timesteps(plan_file):
    with hp.File(plan_file) as f:
        plan_info = f["/Plan Data/Plan Information"].attrs
        

        orig_start_time = datetime.datetime.strptime(
            plan_info["Simulation Start Time"].decode("UTF-8"), "%d%b%Y %H:%M:%S"
        )
        start_time = datetime.datetime.strptime(
            plan_info["Simulation Start Time"].decode("UTF-8"), "%d%b%Y %H:%M:%S"
        )
        end_time = datetime.datetime.strptime(
            plan_info["Simulation End Time"].decode("UTF-8"), "%d%b%Y %H:%M:%S"
        )

        interval = plan_info["Base Output Interval"].decode("UTF-8")
        temporal_resolution = int(re.findall(r"\d", interval)[0])

    out = []
    delta = datetime.timedelta(minutes=temporal_resolution)
    while start_time <= end_time:
        out.append(start_time)
        start_time = start_time + delta
    return orig_start_time, out

# %%
def get_values(hdf_file, structure_idxs, prefix, idx_dict):
    start_time, timesteps = get_timesteps(hdf_file)
    with hp.File(hdf_file) as f:
        keys = list(f['Results/Unsteady/Output/Output Blocks/Base Output/Unsteady Time Series/SA 2D Area Conn'].keys())

        keys_dict = {
            re.findall(r"\D(\d{5})\D", key)[0]: key for key in keys if len(re.findall(r"\D(\d{5})\D", key))>0
        }
        
        search_structures = set(structure_idxs.to_list())

        good_keys = {k:v for k, v in keys_dict.items() if k in search_structures}
        

        max_flow_list = list()
        max_wse_list = list()
        max_tw_wse_list = list()
        timestep_list = list()
        found_keys_list = list()
        for k, v in good_keys.items():
            found_keys_list.append(k)
            data_arr = f[f"Results/Unsteady/Output/Output Blocks/Base Output/Unsteady Time Series/SA 2D Area Conn/{v}/Structure Variables"][:]

            flow_index = idx_dict[k].FlowIndex
            hw_index = idx_dict[k].HWIndex
            tw_index = idx_dict[k].TWIndex
            max_flow_list.append(data_arr[:, flow_index].max())
            abs_max_wse = data_arr[:, hw_index].max()

            max_wse_list.append(abs_max_wse)


            close_max_wse = abs_max_wse * 0.99998

            wse_within_range = data_arr[:, hw_index] >= close_max_wse


            close_timestep = timesteps[np.argmax(wse_within_range)]
            timestep_list.append(close_timestep)

            max_tw_wse_list.append(data_arr[:, tw_index].max())
            
    out = pd.DataFrame({'Structure': found_keys_list, f'{prefix}_Max_Flow': max_flow_list, f'{prefix}_Max_HW_WSE': max_wse_list, f'{prefix}_Max HW WSE Timestep (99%)': timestep_list, f'{prefix}_Max_TW_WSE': max_tw_wse_list, f'{prefix}_Start_Time': [start_time]*len(max_flow_list)})
    out.loc[:, f'{prefix}_Time_Diff'] = out[f'{prefix}_Max HW WSE Timestep (99%)'] - out[f'{prefix}_Start_Time']
    return out

# %%
to_concat = []
for ix, df in data_index.groupby(['Weir'], as_index=False):
    full_path = df.Path_Full.iloc[0]
    base_path = df.Path_Base.iloc[0]

    idx_dict = {row.Structure : row for _, row in df.iterrows()}
    if os.path.exists(base_path):
        base_values = get_values(base_path, df.Structure, 'base', idx_dict)
        
        df = df.merge(base_values, on='Structure')
        #to_concat.append(df)
    if os.path.exists(full_path):
        full_values = get_values(full_path, df.Structure, 'full', idx_dict)
        df = df.merge(full_values, on='Structure')
    to_concat.append(df)
all_results = pd.concat(to_concat)

# %%
all_results.to_csv('structure_values.csv')
